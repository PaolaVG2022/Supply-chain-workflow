# %% [markdown]
# # My Learning Journey
# This is a regular sentence. I do not need a hashtag at the start of this line.
#
# ## Today's Topic
# Here are my main notes:
# * This is a **bold** point.
# * This is an *italic* point.
